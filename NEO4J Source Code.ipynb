# %% [markdown]
# ### Project Name : Employee Performance Analysis INX Future Inc.

# %% [markdown]
# ### Source Code :

# %% [markdown]
# ### Data Pre-Processing :

# %% [markdown]
# ### Step-1 : Importing the necessary Libraries

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from math import sqrt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import warnings
import itertools
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Step-2 : Importing the Data set

# %%
Data = pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')

# %%
#2.1 Displaying the shape to know the status of the dataset:
Data.shape
# Out:
# (1200, 28)

# %%
Data.size
# Out:
# 33600

# %%
#2.2 Displaying the entire data of the header names(column names) with top of the  records from the given dataset file.

Data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  4  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %%
#2.3 Displaying the entire data of the header names(column names) with bottom of the  records from the given dataset file.
Data.tail()
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
# 1197   E100994   50    Male             Medical       Married   Development
# 1198   E100995   34  Female             Medical        Single  Data Science
# 1199   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 1195                  1  ...                            2
# 1196                  2  ...                            1
# 1197                  1  ...                            3
# 1198                  3  ...                            2
# 1199                  2  ...                            1
#
#       TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 1195                           6                      3                   3
# 1196                           4                      2                   3
# 1197                          20                      3                   3
# 1198                           9                      3                   4
# 1199                           4                      3                   3
#
#       ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 1195                             6                             5
# 1196                             1                             0
# 1197                            20                             8
# 1198                             8                             7
# 1199                             2                             2
#
#      YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 1195                       0                     4         No
# 1196                       0                     0         No
# 1197                       3                     8         No
# 1198                       7                     7         No
# 1199                       2                     0        Yes
#
#       PerformanceRating
# 1195                  4
# 1196                  3
# 1197                  3
# 1198                  3
# 1199                  2
#
# [5 rows x 28 columns]

# %%
#2.4 Display the full information of the data with the data types, and their summary of the records : 

Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
#  12  EmpJobInvolvement             1200 non-null   int64
#  13  EmpJobLevel                   1200 non-null   int64
#  14  EmpJobSatisfaction            1200 non-null   int64
#  15  NumCompaniesWorked            1200 non-null   int64
#  16  OverTime                      1200 non-null   object
#  17  EmpLastSalaryHikePercent      1200 non-null   int64
#  18  EmpRelationshipSatisfaction   1200 non-null   int64
#  19  TotalWorkExperienceInYears    1200 non-null   int64
#  20  TrainingTimesLastYear         1200 non-null   int64
#  21  EmpWorkLifeBalance            1200 non-null   int64
#  22  ExperienceYearsAtThisCompany  1200 non-null   int64
#  23  ExperienceYearsInCurrentRole  1200 non-null   int64
#  24  YearsSinceLastPromotion       1200 non-null   int64
#  25  YearsWithCurrManager          1200 non-null   int64
#  26  Attrition                     1200 non-null   object
#  27  PerformanceRating             1200 non-null   int64
# dtypes: int64(19), object(9)
# memory usage: 262.6+ KB

# %% [markdown]
# ### Step-3 : Handiling the Missing data

# %%
# 3.1. Check for missing values ot be findout the Nan values or missing values:
#      1. Displaying the Nan values from the entire dataset, and displaying their summary of the individual columns.      
Data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# PerformanceRating               0
# dtype: int64

# %%
##3.2. Summary of the total Nan values :
Data.isnull().sum().sum()
# Out:
# 0

# %%
## 3.3 . Visualizing the missing values
sns.heatmap(Data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #### 3.4 checking Special characters :

# %%
#1.Displaying entire dataset again to be check special characters in that data.
Data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  4  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %%
# Filling the special characters with the NaN.
Data.replace(['$','*','?','-'],np.nan,inplace=True)

# %%
# Displaying  the entire dataset to be check particular special character place, either its 
# changed to as per the NaN.
Data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  4  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %%
# Cheking the  Nan values of status again after filled the cpecial characters
Data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# PerformanceRating               0
# dtype: int64

# %%
Data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### 3.5. Dealing with the Nan values (missng values):

# %%
# Displaying  the entire dataset to be check particular Nan values place, either its 
# changed or not.
Data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  4  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %%
# Cheking the  Nan values of status again after filled the all Nan values
Data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# PerformanceRating               0
# dtype: int64

# %%
Data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### 3.6. Checking Duplicates exist in the dataset :

# %%
# It is recommended to check for duplicates right after dealing with NaN values
Data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  4  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %%
Data.duplicated()                  #checks for duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# Length: 1200, dtype: bool

# %%
Data[Data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %%
Data.duplicated().sum()
# Out:
# 0

# %%
Data.duplicated().value_counts()
# Out:
# False    1200
# Name: count, dtype: int64

# %%
Data.shape    # Orgianl records = 1200, after duplication = 1200
# Out:
# (1200, 28)

# %%
Data.duplicated().sum()
# Out:
# 0

# %%
Neo4jDB = Data
Neo4jDB
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# 2               Sales   Sales Executive       Travel_Frequently
# 3     Human Resources           Manager           Travel_Rarely
# 4               Sales   Sales Executive           Travel_Rarely
# ...               ...               ...                     ...
# 1195            Sales   Sales Executive       Travel_Frequently
# 1196      Development  Senior Developer           Travel_Rarely
# 1197      Development  Senior Developer           Travel_Rarely
# 1198     Data Science    Data Scientist           Travel_Rarely
# 1199            Sales   Sales Executive           Travel_Rarely
#
#       DistanceFromHome  EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                   10                  3  ...                            4
# 1                   14                  4  ...                            4
# 2                    5                  4  ...                            3
# 3                   10                  4  ...                            2
# 4                   16                  4  ...                            4
# ...                ...                ...  ...                          ...
# 1195                 3                  1  ...                            2
# 1196                10                  2  ...                            1
# 1197                28                  1  ...                            3
# 1198                 9                  3  ...                            2
# 1199                 3                  2  ...                            1
#
#       TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                             10                      2                   2
# 1                             20                      2                   3
# 2                             20                      2                   3
# 3                             23                      2                   2
# 4                             10                      1                   3
# ...                          ...                    ...                 ...
# 1195                           6                      3                   3
# 1196                           4                      2                   3
# 1197                          20                      3                   3
# 1198                           9                      3                   4
# 1199                           4                      3                   3
#
#       ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                               10                             7
# 1                                7                             7
# 2                               18                            13
# 3                               21                             6
# 4                                2                             2
# ...                            ...                           ...
# 1195                             6                             5
# 1196                             1                             0
# 1197                            20                             8
# 1198                             8                             7
# 1199                             2                             2
#
#      YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 0                          0                     8         No
# 1                          1                     7         No
# 2                          1                    12         No
# 3                         12                     6         No
# 4                          2                     2         No
# ...                      ...                   ...        ...
# 1195                       0                     4         No
# 1196                       0                     0         No
# 1197                       3                     8         No
# 1198                       7                     7         No
# 1199                       2                     0        Yes
#
#       PerformanceRating
# 0                     3
# 1                     3
# 2                     4
# 3                     3
# 4                     3
# ...                 ...
# 1195                  4
# 1196                  3
# 1197                  3
# 1198                  3
# 1199                  2
#
# [1200 rows x 28 columns]

# %%
# Dropping the first columns as it is of no use for analysis.
Data.drop(['EmpNumber'],inplace=True,axis=1)

# %%
Data.head()
# Out:
#    Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0   32   Male           Marketing        Single            Sales
# 1   47   Male           Marketing        Single            Sales
# 2   40   Male       Life Sciences       Married            Sales
# 3   41   Male     Human Resources      Divorced  Human Resources
# 4   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 0                  3                           4  ...
# 1                  4                           4  ...
# 2                  4                           4  ...
# 3                  4                           2  ...
# 4                  4                           1  ...
#
#    EmpRelationshipSatisfaction  TotalWorkExperienceInYears  \
# 0                            4                          10
# 1                            4                          20
# 2                            3                          20
# 3                            2                          23
# 4                            4                          10
#
#    TrainingTimesLastYear  EmpWorkLifeBalance  ExperienceYearsAtThisCompany  \
# 0                      2                   2                            10
# 1                      2                   3                             7
# 2                      2                   3                            18
# 3                      2                   2                            21
# 4                      1                   3                             2
#
#   ExperienceYearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                            7                        0                     8
# 1                            7                        1                     7
# 2                           13                        1                    12
# 3                            6                       12                     6
# 4                            2                        2                     2
#
#    Attrition  PerformanceRating
# 0         No                  3
# 1         No                  3
# 2         No                  4
# 3         No                  3
# 4         No                  3
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Exploratory Data Analysis
# ### 2. Department wise performances of the Exploratory Data Analysis (EDA)

# %%
Data.head()
# Out:
#    Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0   32   Male           Marketing        Single            Sales
# 1   47   Male           Marketing        Single            Sales
# 2   40   Male       Life Sciences       Married            Sales
# 3   41   Male     Human Resources      Divorced  Human Resources
# 4   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 0                  3                           4  ...
# 1                  4                           4  ...
# 2                  4                           4  ...
# 3                  4                           2  ...
# 4                  4                           1  ...
#
#    EmpRelationshipSatisfaction  TotalWorkExperienceInYears  \
# 0                            4                          10
# 1                            4                          20
# 2                            3                          20
# 3                            2                          23
# 4                            4                          10
#
#    TrainingTimesLastYear  EmpWorkLifeBalance  ExperienceYearsAtThisCompany  \
# 0                      2                   2                            10
# 1                      2                   3                             7
# 2                      2                   3                            18
# 3                      2                   2                            21
# 4                      1                   3                             2
#
#   ExperienceYearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                            7                        0                     8
# 1                            7                        1                     7
# 2                           13                        1                    12
# 3                            6                       12                     6
# 4                            2                        2                     2
#
#    Attrition  PerformanceRating
# 0         No                  3
# 1         No                  3
# 2         No                  4
# 3         No                  3
# 4         No                  3
#
# [5 rows x 27 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           1200 non-null   int64
#  1   Gender                        1200 non-null   object
#  2   EducationBackground           1200 non-null   object
#  3   MaritalStatus                 1200 non-null   object
#  4   EmpDepartment                 1200 non-null   object
#  5   EmpJobRole                    1200 non-null   object
#  6   BusinessTravelFrequency       1200 non-null   object
#  7   DistanceFromHome              1200 non-null   int64
#  8   EmpEducationLevel             1200 non-null   int64
#  9   EmpEnvironmentSatisfaction    1200 non-null   int64
#  10  EmpHourlyRate                 1200 non-null   int64
#  11  EmpJobInvolvement             1200 non-null   int64
#  12  EmpJobLevel                   1200 non-null   int64
#  13  EmpJobSatisfaction            1200 non-null   int64
#  14  NumCompaniesWorked            1200 non-null   int64
#  15  OverTime                      1200 non-null   object
#  16  EmpLastSalaryHikePercent      1200 non-null   int64
#  17  EmpRelationshipSatisfaction   1200 non-null   int64
#  18  TotalWorkExperienceInYears    1200 non-null   int64
#  19  TrainingTimesLastYear         1200 non-null   int64
#  20  EmpWorkLifeBalance            1200 non-null   int64
#  21  ExperienceYearsAtThisCompany  1200 non-null   int64
#  22  ExperienceYearsInCurrentRole  1200 non-null   int64
#  23  YearsSinceLastPromotion       1200 non-null   int64
#  24  YearsWithCurrManager          1200 non-null   int64
#  25  Attrition                     1200 non-null   object
#  26  PerformanceRating             1200 non-null   int64
# dtypes: int64(19), object(8)
# memory usage: 253.3+ KB

# %%
Data.nunique()
# Out:
# Age                             43
# Gender                           2
# EducationBackground              6
# MaritalStatus                    3
# EmpDepartment                    6
# EmpJobRole                      19
# BusinessTravelFrequency          3
# DistanceFromHome                29
# EmpEducationLevel                5
# EmpEnvironmentSatisfaction       4
# EmpHourlyRate                   71
# EmpJobInvolvement                4
# EmpJobLevel                      5
# EmpJobSatisfaction               4
# NumCompaniesWorked              10
# OverTime                         2
# EmpLastSalaryHikePercent        15
# EmpRelationshipSatisfaction      4
# TotalWorkExperienceInYears      40
# TrainingTimesLastYear            7
# EmpWorkLifeBalance               4
# ExperienceYearsAtThisCompany    37
# ExperienceYearsInCurrentRole    19
# YearsSinceLastPromotion         16
# YearsWithCurrManager            18
# Attrition                        2
# PerformanceRating                3
# dtype: int64

# %%
# identifying the types of Departments
Data["EmpDepartment"].unique()#Here displayed the columun'EmpDepartment' of number of unique numbers
# Out:
# array(['Sales', 'Human Resources', 'Development', 'Data Science',
#        'Research & Development', 'Finance'], dtype=object)

# %%
Data["EmpDepartment"].nunique()
# Out:
# 6

# %%
Data.loc[:,"EmpDepartment"].value_counts()
# Out:
# EmpDepartment
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: count, dtype: int64

# %%
Data.loc[:,"PerformanceRating"].value_counts()
# Out:
# PerformanceRating
# 3    874
# 2    194
# 4    132
# Name: count, dtype: int64

# %%
pd.crosstab(index=Data["EmpDepartment"], columns=Data["PerformanceRating"])
# Out:
# PerformanceRating        2    3   4
# EmpDepartment
# Data Science             1   17   2
# Development             13  304  44
# Finance                 15   30   4
# Human Resources         10   38   6
# Research & Development  68  234  41
# Sales                   87  251  35

# %% [markdown]
# ### Relationship Analysis between the Department & Performance Rating

# %%
Dep = Data.loc[:,['EmpDepartment','PerformanceRating']]
Dep
# Out:
#         EmpDepartment  PerformanceRating
# 0               Sales                  3
# 1               Sales                  3
# 2               Sales                  4
# 3     Human Resources                  3
# 4               Sales                  3
# ...               ...                ...
# 1195            Sales                  4
# 1196      Development                  3
# 1197      Development                  3
# 1198     Data Science                  3
# 1199            Sales                  2
#
# [1200 rows x 2 columns]

# %%
sns.pairplot(Dep)

# %%
DF = Data.groupby("EmpDepartment")["PerformanceRating"].sum()
DF
# Out:
# EmpDepartment
# Data Science                61
# Development               1114
# Finance                    136
# Human Resources            158
# Research & Development    1002
# Sales                     1067
# Name: PerformanceRating, dtype: int64

# %%
pie, ax = plt.subplots(figsize=[8,8])
labels = DF.keys()
plt.pie( x = DF, autopct = "%.01f%%", labels=labels)
plt.title("Department wise Analysis", fontsize =5)
#pie.savefig("Delivery Piechart.png")
# Out:
# Text(0.5, 1.0, 'Department wise Analysis')

# %%
plt.figure(figsize=(10,4.5))
DF.plot.bar()
# Out:
# <Axes: xlabel='EmpDepartment'>

# %%
plt.figure(figsize=(10,4.5))
sns.countplot( x = Data["PerformanceRating"], hue = Data["EmpDepartment"])
# Out:
# <Axes: xlabel='PerformanceRating', ylabel='count'>

# %% [markdown]
# #### Creating a new dataframe to analyze each department separately

# %%
department = pd.get_dummies(Data['EmpDepartment'])
performance = pd.DataFrame(Data['PerformanceRating'])
dept_rating = pd.concat([department,performance],axis=1)

# %%
# Plotting a separate bar graph for performance of each department using seaborn
plt.figure(figsize=(15,10))

# Subplot 1
plt.subplot(2,3,1)
sns.barplot(x='PerformanceRating', y='Sales', data=dept_rating)

# Subplot 2
plt.subplot(2,3,2)
sns.barplot(x='PerformanceRating', y='Development', data=dept_rating)

# Subplot 3
plt.subplot(2,3,3)
sns.barplot(x='PerformanceRating', y='Research & Development', data=dept_rating)

# Subplot 4
plt.subplot(2,3,4)
sns.barplot(x='PerformanceRating', y='Human Resources', data=dept_rating)

# Subplot 5
plt.subplot(2,3,5)
sns.barplot(x='PerformanceRating', y='Finance', data=dept_rating)

# Subplot 6
plt.subplot(2,3,6)
sns.barplot(x='PerformanceRating', y='Data Science', data=dept_rating)

plt.show()

# %% [markdown]
# ### Data Processing/ Data Munging

# %% [markdown]
# ### Step-4. Encoding  Categorical Data  :

# %%
# The following command allows the dataset to be examined for categorical value:
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           1200 non-null   int64
#  1   Gender                        1200 non-null   object
#  2   EducationBackground           1200 non-null   object
#  3   MaritalStatus                 1200 non-null   object
#  4   EmpDepartment                 1200 non-null   object
#  5   EmpJobRole                    1200 non-null   object
#  6   BusinessTravelFrequency       1200 non-null   object
#  7   DistanceFromHome              1200 non-null   int64
#  8   EmpEducationLevel             1200 non-null   int64
#  9   EmpEnvironmentSatisfaction    1200 non-null   int64
#  10  EmpHourlyRate                 1200 non-null   int64
#  11  EmpJobInvolvement             1200 non-null   int64
#  12  EmpJobLevel                   1200 non-null   int64
#  13  EmpJobSatisfaction            1200 non-null   int64
#  14  NumCompaniesWorked            1200 non-null   int64
#  15  OverTime                      1200 non-null   object
#  16  EmpLastSalaryHikePercent      1200 non-null   int64
#  17  EmpRelationshipSatisfaction   1200 non-null   int64
#  18  TotalWorkExperienceInYears    1200 non-null   int64
#  19  TrainingTimesLastYear         1200 non-null   int64
#  20  EmpWorkLifeBalance            1200 non-null   int64
#  21  ExperienceYearsAtThisCompany  1200 non-null   int64
#  22  ExperienceYearsInCurrentRole  1200 non-null   int64
#  23  YearsSinceLastPromotion       1200 non-null   int64
#  24  YearsWithCurrManager          1200 non-null   int64
#  25  Attrition                     1200 non-null   object
#  26  PerformanceRating             1200 non-null   int64
# dtypes: int64(19), object(8)
# memory usage: 253.3+ KB

# %%
Data.dtypes.value_counts()
# Out:
# int64     19
# object     8
# Name: count, dtype: int64

# %%
#Using the LabelEncoding to  converting categorical data(dtypes of objects) into 
#numerical data(dtyps of integers).
#syntax : data.categorical_data = encoder.fit_transform(data.categorical_data
encoder = LabelEncoder()

# %%
#Data.EmpNumber = encoder.fit_transform(Data.EmpNumber)
Data.Gender  = encoder.fit_transform(Data.Gender)
Data.EducationBackground  = encoder.fit_transform(Data.EducationBackground )
Data.MaritalStatus = encoder.fit_transform(Data.MaritalStatus)
Data.EmpDepartment = encoder.fit_transform(Data.EmpDepartment)
Data.EmpJobRole = encoder.fit_transform(Data.EmpJobRole)
Data.BusinessTravelFrequency = encoder.fit_transform(Data.BusinessTravelFrequency)
Data.OverTime  = encoder.fit_transform(Data.OverTime )
Data.Attrition  = encoder.fit_transform(Data.Attrition )

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           1200 non-null   int64
#  1   Gender                        1200 non-null   int32
#  2   EducationBackground           1200 non-null   int32
#  3   MaritalStatus                 1200 non-null   int32
#  4   EmpDepartment                 1200 non-null   int32
#  5   EmpJobRole                    1200 non-null   int32
#  6   BusinessTravelFrequency       1200 non-null   int32
#  7   DistanceFromHome              1200 non-null   int64
#  8   EmpEducationLevel             1200 non-null   int64
#  9   EmpEnvironmentSatisfaction    1200 non-null   int64
#  10  EmpHourlyRate                 1200 non-null   int64
#  11  EmpJobInvolvement             1200 non-null   int64
#  12  EmpJobLevel                   1200 non-null   int64
#  13  EmpJobSatisfaction            1200 non-null   int64
#  14  NumCompaniesWorked            1200 non-null   int64
#  15  OverTime                      1200 non-null   int32
#  16  EmpLastSalaryHikePercent      1200 non-null   int64
#  17  EmpRelationshipSatisfaction   1200 non-null   int64
#  18  TotalWorkExperienceInYears    1200 non-null   int64
#  19  TrainingTimesLastYear         1200 non-null   int64
#  20  EmpWorkLifeBalance            1200 non-null   int64
#  21  ExperienceYearsAtThisCompany  1200 non-null   int64
#  22  ExperienceYearsInCurrentRole  1200 non-null   int64
#  23  YearsSinceLastPromotion       1200 non-null   int64
#  24  YearsWithCurrManager          1200 non-null   int64
#  25  Attrition                     1200 non-null   int32
#  26  PerformanceRating             1200 non-null   int64
# dtypes: int32(8), int64(19)
# memory usage: 215.8 KB

# %% [markdown]
# ### Pre-processed Data :

# %%
# Checking the final pre-processed Data :
Data.head()
# Out:
#    Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0   32       1                    2              2              5          13
# 1   47       1                    2              2              5          13
# 2   40       1                    1              1              5          13
# 3   41       1                    0              0              3           8
# 4   60       1                    2              2              5          13
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0                        2                10                  3
# 1                        2                14                  4
# 2                        1                 5                  4
# 3                        2                10                  4
# 4                        2                16                  4
#
#    EmpEnvironmentSatisfaction  ...  EmpRelationshipSatisfaction  \
# 0                           4  ...                            4
# 1                           4  ...                            4
# 2                           4  ...                            3
# 3                           2  ...                            2
# 4                           1  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                        0                     8          0                  3
# 1                        1                     7          0                  3
# 2                        1                    12          0                  4
# 3                       12                     6          0                  3
# 4                        2                     2          0                  3
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Data Describing & checking Correlation to  Select the Target fields

# %%
Data.describe()  # It is only to calculate the data types of integers & floats only
# Out:
#                Age       Gender  EducationBackground  MaritalStatus  \
# count  1200.000000  1200.000000           1200.00000    1200.000000
# mean     36.918333     0.604167              2.23500       1.096667
# std       9.087289     0.489233              1.31004       0.731050
# min      18.000000     0.000000              0.00000       0.000000
# 25%      30.000000     0.000000              1.00000       1.000000
# 50%      36.000000     1.000000              2.00000       1.000000
# 75%      43.000000     1.000000              3.00000       2.000000
# max      60.000000     1.000000              5.00000       2.000000
#
#        EmpDepartment   EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# count    1200.000000  1200.000000              1200.000000       1200.000000
# mean        3.215000     9.039167                 1.595000          9.165833
# std         1.696911     4.754451                 0.679234          8.176636
# min         0.000000     0.000000                 0.000000          1.000000
# 25%         1.000000     4.000000                 1.000000          2.000000
# 50%         4.000000     9.000000                 2.000000          7.000000
# 75%         5.000000    13.000000                 2.000000         14.000000
# max         5.000000    18.000000                 2.000000         29.000000
#
#        EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# count         1200.00000                 1200.000000  ...
# mean             2.89250                    2.715833  ...
# std              1.04412                    1.090599  ...
# min              1.00000                    1.000000  ...
# 25%              2.00000                    2.000000  ...
# 50%              3.00000                    3.000000  ...
# 75%              4.00000                    4.000000  ...
# max              5.00000                    4.000000  ...
#
#        EmpRelationshipSatisfaction  TotalWorkExperienceInYears  \
# count                  1200.000000                 1200.000000
# mean                      2.725000                   11.330000
# std                       1.075642                    7.797228
# min                       1.000000                    0.000000
# 25%                       2.000000                    6.000000
# 50%                       3.000000                   10.000000
# 75%                       4.000000                   15.000000
# max                       4.000000                   40.000000
#
#        TrainingTimesLastYear  EmpWorkLifeBalance  \
# count            1200.000000         1200.000000
# mean                2.785833            2.744167
# std                 1.263446            0.699374
# min                 0.000000            1.000000
# 25%                 2.000000            2.000000
# 50%                 3.000000            3.000000
# 75%                 3.000000            3.000000
# max                 6.000000            4.000000
#
#        ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# count                   1200.000000                   1200.000000
# mean                       7.077500                      4.291667
# std                        6.236899                      3.613744
# min                        0.000000                      0.000000
# 25%                        3.000000                      2.000000
# 50%                        5.000000                      3.000000
# 75%                       10.000000                      7.000000
# max                       40.000000                     18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager    Attrition  \
# count              1200.000000           1200.000000  1200.000000
# mean                  2.194167              4.105000     0.148333
# std                   3.221560              3.541576     0.355578
# min                   0.000000              0.000000     0.000000
# 25%                   0.000000              2.000000     0.000000
# 50%                   1.000000              3.000000     0.000000
# 75%                   3.000000              7.000000     0.000000
# max                  15.000000             17.000000     1.000000
#
#        PerformanceRating
# count        1200.000000
# mean            2.948333
# std             0.518866
# min             2.000000
# 25%             3.000000
# 50%             3.000000
# 75%             3.000000
# max             4.000000
#
# [8 rows x 27 columns]

# %%
Data.corr()
# Out:
#                                    Age    Gender  EducationBackground  \
# Age                           1.000000 -0.040107            -0.055905
# Gender                       -0.040107  1.000000             0.009922
# EducationBackground          -0.055905  0.009922             1.000000
# MaritalStatus                -0.098368 -0.042169            -0.001097
# EmpDepartment                -0.000104 -0.010925            -0.026874
# EmpJobRole                   -0.037665  0.011332            -0.012325
# BusinessTravelFrequency       0.040579 -0.043608             0.012382
# DistanceFromHome              0.020937 -0.001507            -0.013919
# EmpEducationLevel             0.207313 -0.022960            -0.047978
# EmpEnvironmentSatisfaction    0.013814  0.000033             0.045028
# EmpHourlyRate                 0.062867  0.002218            -0.030234
# EmpJobInvolvement             0.027216  0.010949            -0.025505
# EmpJobLevel                   0.509139 -0.050685            -0.056338
# EmpJobSatisfaction           -0.002436  0.024680            -0.030977
# NumCompaniesWorked            0.284408 -0.036675            -0.032879
# OverTime                      0.051910 -0.038410             0.007046
# EmpLastSalaryHikePercent     -0.006105 -0.005319            -0.009788
# EmpRelationshipSatisfaction   0.049749  0.030707             0.005652
# TotalWorkExperienceInYears    0.680886 -0.061055            -0.027929
# TrainingTimesLastYear        -0.016053 -0.057654             0.051596
# EmpWorkLifeBalance           -0.019563  0.015793             0.022890
# ExperienceYearsAtThisCompany  0.318852 -0.030392            -0.009887
# ExperienceYearsInCurrentRole  0.217163 -0.031823            -0.003215
# YearsSinceLastPromotion       0.228199 -0.021575             0.014277
# YearsWithCurrManager          0.205098 -0.036643             0.002767
# Attrition                    -0.189317  0.035758             0.027161
# PerformanceRating            -0.040164 -0.001780             0.005607
#
#                               MaritalStatus  EmpDepartment  EmpJobRole  \
# Age                               -0.098368      -0.000104   -0.037665
# Gender                            -0.042169      -0.010925    0.011332
# EducationBackground               -0.001097      -0.026874   -0.012325
# MaritalStatus                      1.000000       0.067272    0.038023
# EmpDepartment                      0.067272       1.000000    0.568973
# EmpJobRole                         0.038023       0.568973    1.000000
# BusinessTravelFrequency            0.028520      -0.045233   -0.086251
# DistanceFromHome                  -0.019148       0.007707    0.022939
# EmpEducationLevel                  0.026737       0.019175   -0.016792
# EmpEnvironmentSatisfaction        -0.032467      -0.019237    0.044612
# EmpHourlyRate                     -0.013540       0.003957   -0.016179
# EmpJobInvolvement                 -0.043355      -0.076988   -0.008034
# EmpJobLevel                       -0.087359       0.100526    0.004406
# EmpJobSatisfaction                 0.044593       0.007150    0.032916
# NumCompaniesWorked                -0.030095      -0.033950   -0.009111
# OverTime                          -0.022833      -0.026841    0.015075
# EmpLastSalaryHikePercent           0.010128      -0.012661    0.005735
# EmpRelationshipSatisfaction        0.026410      -0.050286   -0.043067
# TotalWorkExperienceInYears        -0.093537       0.016065   -0.049529
# TrainingTimesLastYear              0.026045       0.016438    0.004452
# EmpWorkLifeBalance                 0.014154       0.068875   -0.007519
# ExperienceYearsAtThisCompany      -0.075728       0.047677   -0.009047
# ExperienceYearsInCurrentRole      -0.076663       0.069602    0.019383
# YearsSinceLastPromotion           -0.052951       0.052315    0.012190
# YearsWithCurrManager              -0.061908       0.033850   -0.004504
# Attrition                          0.162969       0.048006    0.037508
# PerformanceRating                  0.024172      -0.162615   -0.096209
#
#                               BusinessTravelFrequency  DistanceFromHome  \
# Age                                          0.040579          0.020937
# Gender                                      -0.043608         -0.001507
# EducationBackground                          0.012382         -0.013919
# MaritalStatus                                0.028520         -0.019148
# EmpDepartment                               -0.045233          0.007707
# EmpJobRole                                  -0.086251          0.022939
# BusinessTravelFrequency                      1.000000         -0.020935
# DistanceFromHome                            -0.020935          1.000000
# EmpEducationLevel                            0.002064          0.045856
# EmpEnvironmentSatisfaction                   0.012267         -0.017719
# EmpHourlyRate                                0.025400          0.013730
# EmpJobInvolvement                            0.016652          0.003231
# EmpJobLevel                                  0.036360          0.017270
# EmpJobSatisfaction                          -0.031236         -0.003036
# NumCompaniesWorked                           0.021476         -0.021411
# OverTime                                     0.032229          0.024940
# EmpLastSalaryHikePercent                    -0.041946          0.044974
# EmpRelationshipSatisfaction                 -0.032705         -0.009509
# TotalWorkExperienceInYears                   0.042736          0.027306
# TrainingTimesLastYear                        0.006720         -0.032082
# EmpWorkLifeBalance                          -0.040969         -0.044788
# ExperienceYearsAtThisCompany                -0.015029          0.021908
# ExperienceYearsInCurrentRole                -0.006541          0.019898
# YearsSinceLastPromotion                     -0.020824          0.013246
# YearsWithCurrManager                        -0.028073          0.017860
# Attrition                                    0.007217          0.063248
# PerformanceRating                           -0.031025         -0.046142
#
#                               EmpEducationLevel  EmpEnvironmentSatisfaction  \
# Age                                    0.207313                    0.013814
# Gender                                -0.022960                    0.000033
# EducationBackground                   -0.047978                    0.045028
# MaritalStatus                          0.026737                   -0.032467
# EmpDepartment                          0.019175                   -0.019237
# EmpJobRole                            -0.016792                    0.044612
# BusinessTravelFrequency                0.002064                    0.012267
# DistanceFromHome                       0.045856                   -0.017719
# EmpEducationLevel                      1.000000                   -0.037103
# EmpEnvironmentSatisfaction            -0.037103                    1.000000
# EmpHourlyRate                          0.014095                   -0.049501
# EmpJobInvolvement                      0.027544                    0.004865
# EmpJobLevel                            0.100734                   -0.008272
# EmpJobSatisfaction                     0.000357                   -0.004319
# NumCompaniesWorked                     0.128674                    0.017270
# OverTime                              -0.021119                    0.064270
# EmpLastSalaryHikePercent               0.002358                   -0.047271
# EmpRelationshipSatisfaction           -0.016690                   -0.010504
# TotalWorkExperienceInYears             0.151062                   -0.012894
# TrainingTimesLastYear                 -0.013674                    0.001192
# EmpWorkLifeBalance                     0.010276                   -0.000262
# ExperienceYearsAtThisCompany           0.076332                   -0.000561
# ExperienceYearsInCurrentRole           0.066672                    0.025491
# YearsSinceLastPromotion                0.054313                    0.010732
# YearsWithCurrManager                   0.088988                   -0.011702
# Attrition                             -0.049118                   -0.123490
# PerformanceRating                      0.020529                    0.395561
#
#                               ...  EmpRelationshipSatisfaction  \
# Age                           ...                     0.049749
# Gender                        ...                     0.030707
# EducationBackground           ...                     0.005652
# MaritalStatus                 ...                     0.026410
# EmpDepartment                 ...                    -0.050286
# EmpJobRole                    ...                    -0.043067
# BusinessTravelFrequency       ...                    -0.032705
# DistanceFromHome              ...                    -0.009509
# EmpEducationLevel             ...                    -0.016690
# EmpEnvironmentSatisfaction    ...                    -0.010504
# EmpHourlyRate                 ...                     0.008783
# EmpJobInvolvement             ...                     0.018037
# EmpJobLevel                   ...                     0.002992
# EmpJobSatisfaction            ...                    -0.022028
# NumCompaniesWorked            ...                     0.057917
# OverTime                      ...                     0.034146
# EmpLastSalaryHikePercent      ...                    -0.042892
# EmpRelationshipSatisfaction   ...                     1.000000
# TotalWorkExperienceInYears    ...                     0.018089
# TrainingTimesLastYear         ...                     0.025975
# EmpWorkLifeBalance            ...                    -0.004906
# ExperienceYearsAtThisCompany  ...                     0.015612
# ExperienceYearsInCurrentRole  ...                    -0.032131
# YearsSinceLastPromotion       ...                     0.026253
# YearsWithCurrManager          ...                    -0.006426
# Attrition                     ...                    -0.037179
# PerformanceRating             ...                    -0.019502
#
#                               TotalWorkExperienceInYears  \
# Age                                             0.680886
# Gender                                         -0.061055
# EducationBackground                            -0.027929
# MaritalStatus                                  -0.093537
# EmpDepartment                                   0.016065
# EmpJobRole                                     -0.049529
# BusinessTravelFrequency                         0.042736
# DistanceFromHome                                0.027306
# EmpEducationLevel                               0.151062
# EmpEnvironmentSatisfaction                     -0.012894
# EmpHourlyRate                                   0.026034
# EmpJobInvolvement                              -0.028851
# EmpJobLevel                                     0.784229
# EmpJobSatisfaction                             -0.026824
# NumCompaniesWorked                              0.221505
# OverTime                                        0.044233
# EmpLastSalaryHikePercent                       -0.005933
# EmpRelationshipSatisfaction                     0.018089
# TotalWorkExperienceInYears                      1.000000
# TrainingTimesLastYear                          -0.022113
# EmpWorkLifeBalance                              0.015495
# ExperienceYearsAtThisCompany                    0.633555
# ExperienceYearsInCurrentRole                    0.460700
# YearsSinceLastPromotion                         0.412781
# YearsWithCurrManager                            0.460783
# Attrition                                      -0.185226
# PerformanceRating                              -0.068141
#
#                               TrainingTimesLastYear  EmpWorkLifeBalance  \
# Age                                       -0.016053           -0.019563
# Gender                                    -0.057654            0.015793
# EducationBackground                        0.051596            0.022890
# MaritalStatus                              0.026045            0.014154
# EmpDepartment                              0.016438            0.068875
# EmpJobRole                                 0.004452           -0.007519
# BusinessTravelFrequency                    0.006720           -0.040969
# DistanceFromHome                          -0.032082           -0.044788
# EmpEducationLevel                         -0.013674            0.010276
# EmpEnvironmentSatisfaction                 0.001192           -0.000262
# EmpHourlyRate                             -0.024160            0.016189
# EmpJobInvolvement                         -0.025168           -0.014129
# EmpJobLevel                               -0.000389            0.049218
# EmpJobSatisfaction                        -0.028031           -0.018548
# NumCompaniesWorked                        -0.050817            0.002489
# OverTime                                  -0.061398           -0.027968
# EmpLastSalaryHikePercent                  -0.013439           -0.017001
# EmpRelationshipSatisfaction                0.025975           -0.004906
# TotalWorkExperienceInYears                -0.022113            0.015495
# TrainingTimesLastYear                      1.000000            0.037048
# EmpWorkLifeBalance                         0.037048            1.000000
# ExperienceYearsAtThisCompany               0.008564            0.023479
# ExperienceYearsInCurrentRole               0.010222            0.045719
# YearsSinceLastPromotion                    0.018831            0.015773
# YearsWithCurrManager                      -0.013237            0.010518
# Attrition                                 -0.035047           -0.068624
# PerformanceRating                         -0.005443            0.124429
#
#                               ExperienceYearsAtThisCompany  \
# Age                                               0.318852
# Gender                                           -0.030392
# EducationBackground                              -0.009887
# MaritalStatus                                    -0.075728
# EmpDepartment                                     0.047677
# EmpJobRole                                       -0.009047
# BusinessTravelFrequency                          -0.015029
# DistanceFromHome                                  0.021908
# EmpEducationLevel                                 0.076332
# EmpEnvironmentSatisfaction                       -0.000561
# EmpHourlyRate                                    -0.000399
# EmpJobInvolvement                                -0.039720
# EmpJobLevel                                       0.540377
# EmpJobSatisfaction                                0.001807
# NumCompaniesWorked                               -0.129797
# OverTime                                          0.004295
# EmpLastSalaryHikePercent                         -0.019830
# EmpRelationshipSatisfaction                       0.015612
# TotalWorkExperienceInYears                        0.633555
# TrainingTimesLastYear                             0.008564
# EmpWorkLifeBalance                                0.023479
# ExperienceYearsAtThisCompany                      1.000000
# ExperienceYearsInCurrentRole                      0.764102
# YearsSinceLastPromotion                           0.620230
# YearsWithCurrManager                              0.759258
# Attrition                                        -0.142456
# PerformanceRating                                -0.111645
#
#                               ExperienceYearsInCurrentRole  \
# Age                                               0.217163
# Gender                                           -0.031823
# EducationBackground                              -0.003215
# MaritalStatus                                    -0.076663
# EmpDepartment                                     0.069602
# EmpJobRole                                        0.019383
# BusinessTravelFrequency                          -0.006541
# DistanceFromHome                                  0.019898
# EmpEducationLevel                                 0.066672
# EmpEnvironmentSatisfaction                        0.025491
# EmpHourlyRate                                    -0.011871
# EmpJobInvolvement                                 0.002910
# EmpJobLevel                                       0.399235
# EmpJobSatisfaction                                0.002018
# NumCompaniesWorked                               -0.097271
# OverTime                                         -0.015674
# EmpLastSalaryHikePercent                         -0.004957
# EmpRelationshipSatisfaction                      -0.032131
# TotalWorkExperienceInYears                        0.460700
# TrainingTimesLastYear                             0.010222
# EmpWorkLifeBalance                                0.045719
# ExperienceYearsAtThisCompany                      0.764102
# ExperienceYearsInCurrentRole                      1.000000
# YearsSinceLastPromotion                           0.540600
# YearsWithCurrManager                              0.728973
# Attrition                                        -0.173895
# PerformanceRating                                -0.147638
#
#                               YearsSinceLastPromotion  YearsWithCurrManager  \
# Age                                          0.228199              0.205098
# Gender                                      -0.021575             -0.036643
# EducationBackground                          0.014277              0.002767
# MaritalStatus                               -0.052951             -0.061908
# EmpDepartment                                0.052315              0.033850
# EmpJobRole                                   0.012190             -0.004504
# BusinessTravelFrequency                     -0.020824             -0.028073
# DistanceFromHome                             0.013246              0.017860
# EmpEducationLevel                            0.054313              0.088988
# EmpEnvironmentSatisfaction                   0.010732             -0.011702
# EmpHourlyRate                               -0.010000             -0.004576
# EmpJobInvolvement                           -0.019944              0.012924
# EmpJobLevel                                  0.360880              0.374872
# EmpJobSatisfaction                          -0.006508             -0.022096
# NumCompaniesWorked                          -0.031656             -0.109937
# OverTime                                     0.000261             -0.028447
# EmpLastSalaryHikePercent                    -0.015911             -0.007666
# EmpRelationshipSatisfaction                  0.026253             -0.006426
# TotalWorkExperienceInYears                   0.412781              0.460783
# TrainingTimesLastYear                        0.018831             -0.013237
# EmpWorkLifeBalance                           0.015773              0.010518
# ExperienceYearsAtThisCompany                 0.620230              0.759258
# ExperienceYearsInCurrentRole                 0.540600              0.728973
# YearsSinceLastPromotion                      1.000000              0.491199
# YearsWithCurrManager                         0.491199              1.000000
# Attrition                                   -0.057199             -0.158745
# PerformanceRating                           -0.167629             -0.122313
#
#                               Attrition  PerformanceRating
# Age                           -0.189317          -0.040164
# Gender                         0.035758          -0.001780
# EducationBackground            0.027161           0.005607
# MaritalStatus                  0.162969           0.024172
# EmpDepartment                  0.048006          -0.162615
# EmpJobRole                     0.037508          -0.096209
# BusinessTravelFrequency        0.007217          -0.031025
# DistanceFromHome               0.063248          -0.046142
# EmpEducationLevel             -0.049118           0.020529
# EmpEnvironmentSatisfaction    -0.123490           0.395561
# EmpHourlyRate                 -0.026313          -0.043116
# EmpJobInvolvement             -0.153360          -0.010539
# EmpJobLevel                   -0.175763          -0.076632
# EmpJobSatisfaction            -0.081783           0.000606
# NumCompaniesWorked             0.037643           0.020980
# OverTime                       0.224535           0.050206
# EmpLastSalaryHikePercent      -0.009448           0.333722
# EmpRelationshipSatisfaction   -0.037179          -0.019502
# TotalWorkExperienceInYears    -0.185226          -0.068141
# TrainingTimesLastYear         -0.035047          -0.005443
# EmpWorkLifeBalance            -0.068624           0.124429
# ExperienceYearsAtThisCompany  -0.142456          -0.111645
# ExperienceYearsInCurrentRole  -0.173895          -0.147638
# YearsSinceLastPromotion       -0.057199          -0.167629
# YearsWithCurrManager          -0.158745          -0.122313
# Attrition                      1.000000          -0.039796
# PerformanceRating             -0.039796           1.000000
#
# [27 rows x 27 columns]

# %%
corelation = Data.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corelation,annot=True,annot_kws={"size":10},linewidths=1,vmin=0,vmax=0.6,cmap='ocean_r')
plt.title("Correlation Matrix (Data)")
plt.show() # let's make it clear.

# %%
Data.corr().PerformanceRating
# Out:
# Age                            -0.040164
# Gender                         -0.001780
# EducationBackground             0.005607
# MaritalStatus                   0.024172
# EmpDepartment                  -0.162615
# EmpJobRole                     -0.096209
# BusinessTravelFrequency        -0.031025
# DistanceFromHome               -0.046142
# EmpEducationLevel               0.020529
# EmpEnvironmentSatisfaction      0.395561
# EmpHourlyRate                  -0.043116
# EmpJobInvolvement              -0.010539
# EmpJobLevel                    -0.076632
# EmpJobSatisfaction              0.000606
# NumCompaniesWorked              0.020980
# OverTime                        0.050206
# EmpLastSalaryHikePercent        0.333722
# EmpRelationshipSatisfaction    -0.019502
# TotalWorkExperienceInYears     -0.068141
# TrainingTimesLastYear          -0.005443
# EmpWorkLifeBalance              0.124429
# ExperienceYearsAtThisCompany   -0.111645
# ExperienceYearsInCurrentRole   -0.147638
# YearsSinceLastPromotion        -0.167629
# YearsWithCurrManager           -0.122313
# Attrition                      -0.039796
# PerformanceRating               1.000000
# Name: PerformanceRating, dtype: float64

# %%
Data.head()
# Out:
#    Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0   32       1                    2              2              5          13
# 1   47       1                    2              2              5          13
# 2   40       1                    1              1              5          13
# 3   41       1                    0              0              3           8
# 4   60       1                    2              2              5          13
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0                        2                10                  3
# 1                        2                14                  4
# 2                        1                 5                  4
# 3                        2                10                  4
# 4                        2                16                  4
#
#    EmpEnvironmentSatisfaction  ...  EmpRelationshipSatisfaction  \
# 0                           4  ...                            4
# 1                           4  ...                            4
# 2                           4  ...                            3
# 3                           2  ...                            2
# 4                           1  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                        0                     8          0                  3
# 1                        1                     7          0                  3
# 2                        1                    12          0                  4
# 3                       12                     6          0                  3
# 4                        2                     2          0                  3
#
# [5 rows x 27 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           1200 non-null   int64
#  1   Gender                        1200 non-null   int32
#  2   EducationBackground           1200 non-null   int32
#  3   MaritalStatus                 1200 non-null   int32
#  4   EmpDepartment                 1200 non-null   int32
#  5   EmpJobRole                    1200 non-null   int32
#  6   BusinessTravelFrequency       1200 non-null   int32
#  7   DistanceFromHome              1200 non-null   int64
#  8   EmpEducationLevel             1200 non-null   int64
#  9   EmpEnvironmentSatisfaction    1200 non-null   int64
#  10  EmpHourlyRate                 1200 non-null   int64
#  11  EmpJobInvolvement             1200 non-null   int64
#  12  EmpJobLevel                   1200 non-null   int64
#  13  EmpJobSatisfaction            1200 non-null   int64
#  14  NumCompaniesWorked            1200 non-null   int64
#  15  OverTime                      1200 non-null   int32
#  16  EmpLastSalaryHikePercent      1200 non-null   int64
#  17  EmpRelationshipSatisfaction   1200 non-null   int64
#  18  TotalWorkExperienceInYears    1200 non-null   int64
#  19  TrainingTimesLastYear         1200 non-null   int64
#  20  EmpWorkLifeBalance            1200 non-null   int64
#  21  ExperienceYearsAtThisCompany  1200 non-null   int64
#  22  ExperienceYearsInCurrentRole  1200 non-null   int64
#  23  YearsSinceLastPromotion       1200 non-null   int64
#  24  YearsWithCurrManager          1200 non-null   int64
#  25  Attrition                     1200 non-null   int32
#  26  PerformanceRating             1200 non-null   int64
# dtypes: int32(8), int64(19)
# memory usage: 215.8 KB

# %% [markdown]
# ## Feature Selection of Top 3 factors :
# -     There are a lot of columns in the predictor variable. So, the correlation coeffecient is calculated to see which of them are important and these are then used for training methods. From there, we also get the top factors which affect performance. We can see that the most important features selectd were Department, Job Role, Environment Satisfaction, Last Salary Hike Percent, Work Life Balance, Experience Years At This Company, Experience Years In Current Role, Years Since Last Promotion, Years With Current Manager. These were selected because their correlation coeffecient with Performance Rating was more than 0.1.
# -     Standardization and Label Encoding was also used for feature transformation.
# -     A separate analysis considering all the predictors was carried out but it resulted in decreasing the accuracy. Similarly, Principal Component Analysis also reduces the accuracy.
# -     Top 3 factors which affect the employee performance are 1. Employee EnvironmentSatisfaction, 2. Employee Last Salary Hike Percent and 3. Years Since Last Promotion

# %%
X = Data.loc[:,['EmpEnvironmentSatisfaction','EmpLastSalaryHikePercent','YearsSinceLastPromotion']]
Y = Data.loc[:,['PerformanceRating']]

# %% [markdown]
# ### Step-5 : Splitting the Dataset in to Test set and Training test

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size = 0.2,random_state=0)

# %% [markdown]
# ### Step - 6 : Feature Scaling

# %%
# Standardization technique is used
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (960, 3)

# %%
X_test.shape
# Out:
# (240, 3)

# %% [markdown]
# #### MACHINE LEARNING ENGINEERING

# %% [markdown]
# ### Step-7 : Model Selection

# %% [markdown]
# ### 1.Support Vector Machine from SVC Model :

# %%
# Training the model
from sklearn.svm import SVC
Model_svc = SVC(kernel='rbf', C=100,random_state=0)

# %%
Model_svc.fit(X_train, Y_train)
# Out:
# SVC(C=100, random_state=0)

# %%
# Predicting the model
y_predict_svm = Model_svc.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(Y_test,y_predict_svm))
print(classification_report(Y_test,y_predict_svm))
# Out:
# 0.875
#               precision    recall  f1-score   support
#
#            2       0.60      0.82      0.69        33
#            3       0.94      0.89      0.91       179
#            4       0.92      0.86      0.89        28
#
#     accuracy                           0.88       240
#    macro avg       0.82      0.85      0.83       240
# weighted avg       0.89      0.88      0.88       240

# %% [markdown]
# ### 2 .  Random forest Classification Model :

# %%
# Training the model
from sklearn.ensemble import RandomForestClassifier

# %%
modelrf = RandomForestClassifier(n_estimators =48)

# %%
modelrf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(n_estimators=48)

# %%
modelrf.score(X_test,Y_test)*100
# Out:
# 86.25

# %%
# Predicting the model
y_predict_rf = modelrf.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(Y_test,y_predict_rf))
print(classification_report(Y_test,y_predict_rf))
# Out:
# 0.8625
#               precision    recall  f1-score   support
#
#            2       0.60      0.64      0.62        33
#            3       0.92      0.91      0.91       179
#            4       0.86      0.86      0.86        28
#
#     accuracy                           0.86       240
#    macro avg       0.79      0.80      0.79       240
# weighted avg       0.87      0.86      0.86       240

# %% [markdown]
# ### Final Evaluation score of  the model for the Top 3 factors :

# %% [markdown]
# -     In the section below, we used algorithms like 1.Logistic Regression, 2.Support Vector Machine, 3.Decision Tree, 4.Random Forest, 5.XGBoost Classifier to calculate the accuracy and found out that final accuracy scores as per the bellow:
#
#       1. Support Vector Machine from SVC Model  gives the maximum accuracy of 88%.

# %% [markdown]
# ## Feature Selection of Top 10 factors :
# -     There are a lot of columns in the predictor variable. So, the correlation coeffecient is calculated to see which of them are important and these are then used for training methods. From there, we also get the top factors which affect performance. We can see that the most important features selectd were Department, Job Role, Environment Satisfaction, Last Salary Hike Percent, Work Life Balance, Experience Years At This Company, Experience Years In Current Role, Years Since Last Promotion, Years With Current Manager. These were selected because their correlation coeffecient with Performance Rating was more than 0.1.
# -     Standardization and Label Encoding was also used for feature transformation.
# -     A separate analysis considering all the predictors was carried out but it resulted in decreasing the accuracy. Similarly, Principal Component Analysis also reduces the accuracy.
# -     A trained model which can predict the employee performance based on factors as
#       inputs are 1)EmpDepartment,2)EmpJobRole, 3)EmpEnvironmentSatisfaction, 4)EmpLastSalaryHikePercent,5)EmpWorkLifeBalance,6)ExperienceYearsAtThisCompany ,7)ExperienceYearsInCurrentRole,8)YearsSinceLastPromotion, 9)YearsWithCurrManager

# %%
X = Data.iloc[:,[4,5,9,16,20,21,22,23,24]]
X
# Out:
#       EmpDepartment  EmpJobRole  EmpEnvironmentSatisfaction  \
# 0                 5          13                           4
# 1                 5          13                           4
# 2                 5          13                           4
# 3                 3           8                           2
# 4                 5          13                           1
# ...             ...         ...                         ...
# 1195              5          13                           4
# 1196              1          15                           4
# 1197              1          15                           4
# 1198              0           1                           4
# 1199              5          13                           1
#
#       EmpLastSalaryHikePercent  EmpWorkLifeBalance  \
# 0                           12                   2
# 1                           12                   3
# 2                           21                   3
# 3                           15                   2
# 4                           14                   3
# ...                        ...                 ...
# 1195                        20                   3
# 1196                        17                   3
# 1197                        11                   3
# 1198                        14                   4
# 1199                        14                   3
#
#       ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                               10                             7
# 1                                7                             7
# 2                               18                            13
# 3                               21                             6
# 4                                2                             2
# ...                            ...                           ...
# 1195                             6                             5
# 1196                             1                             0
# 1197                            20                             8
# 1198                             8                             7
# 1199                             2                             2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     8
# 1                           1                     7
# 2                           1                    12
# 3                          12                     6
# 4                           2                     2
# ...                       ...                   ...
# 1195                        0                     4
# 1196                        0                     0
# 1197                        3                     8
# 1198                        7                     7
# 1199                        2                     0
#
# [1200 rows x 9 columns]

# %%
len(X)
# Out:
# 1200

# %%
Y = Data.loc[:,['PerformanceRating']]
Y
# Out:
#       PerformanceRating
# 0                     3
# 1                     3
# 2                     4
# 3                     3
# 4                     3
# ...                 ...
# 1195                  4
# 1196                  3
# 1197                  3
# 1198                  3
# 1199                  2
#
# [1200 rows x 1 columns]

# %% [markdown]
# ### Splitting the Dataset in to Test set and Training test

# %%
#x = data.input_features
#y = data.output_features
X = X = Data.iloc[:,[4,5,9,16,20,21,22,23,24]]
Y = Data.loc[:,['PerformanceRating']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size = 0.2,random_state=0)

# %% [markdown]
# ### Feature Scaling

# %%
# Standardization technique is used
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (960, 9)

# %%
X_test.shape
# Out:
# (240, 9)

# %% [markdown]
# ### Model Selection :

# %% [markdown]
# ### 1.Support Vector Machine from SVC Model :

# %%
# Training the model
from sklearn.svm import SVC
Model_svc = SVC(kernel='rbf', C=100, random_state=0)

# %%
Model_svc.fit(X_train, y_train)
# Out:
# SVC(C=100, random_state=0)

# %%
# Predicting the model
y_predict_svm = Model_svc.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_test,y_predict_svm))
print(classification_report(y_test,y_predict_svm))
# Out:
# 0.8666666666666667
#               precision    recall  f1-score   support
#
#            2       0.73      0.82      0.77        33
#            3       0.94      0.89      0.92       179
#            4       0.64      0.75      0.69        28
#
#     accuracy                           0.87       240
#    macro avg       0.77      0.82      0.79       240
# weighted avg       0.88      0.87      0.87       240

# %% [markdown]
# ### 2. Decision Tree Classification Model :

# %%
# Training the model
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
Model_DTC= tree.DecisionTreeClassifier()

# %%
Model_DTC.fit(X_train, y_train )
# Out:
# DecisionTreeClassifier()

# %%
# Predicting the model
y_predict_dtree = Model_DTC.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_test,y_predict_dtree))
print(classification_report(y_test,y_predict_dtree))
# Out:
# 0.9041666666666667
#               precision    recall  f1-score   support
#
#            2       0.73      0.73      0.73        33
#            3       0.93      0.95      0.94       179
#            4       0.96      0.82      0.88        28
#
#     accuracy                           0.90       240
#    macro avg       0.87      0.83      0.85       240
# weighted avg       0.90      0.90      0.90       240

# %% [markdown]
# ### 3 .  Random forest Classification Model :

# %%
# Training the model
from sklearn.ensemble import RandomForestClassifier

# %%
modelrf = RandomForestClassifier(n_estimators =48)

# %%
modelrf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=48)

# %%
modelrf.score(X_test,y_test)*100
# Out:
# 95.0

# %%
# Predicting the model
y_predict_rf = modelrf.predict(X_test)

# %%
# Finding accuracy, precision, recall and confusion matrix
print(accuracy_score(y_test,y_predict_rf))
print(classification_report(y_test,y_predict_rf))
# Out:
# 0.95
#               precision    recall  f1-score   support
#
#            2       0.89      0.94      0.91        33
#            3       0.97      0.97      0.97       179
#            4       0.89      0.86      0.87        28
#
#     accuracy                           0.95       240
#    macro avg       0.92      0.92      0.92       240
# weighted avg       0.95      0.95      0.95       240

# %% [markdown]
# ### Final Evaluation scores of  the models for the Top 10 factors :

# %% [markdown]
# -     In the section below, we used algorithms like 1)Support Vector Machine, 2)Decision Tree, 3)Random Forest, 4)XGBoost Classifier to calculate the accuracy and found out that final accuracy scores as per the bellow:
#
#    1. Random forest Classification Model gives the maximum accuracy of 95%.

# %%
y_predict_rf
# Out:
# array([3, 4, 3, 3, 3, 2, 2, 3, 3, 3, 3, 4, 3, 3, 3, 2, 3, 2, 3, 3, 2, 3,
#        3, 3, 3, 3, 4, 3, 3, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 4,
#        2, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 4, 3, 3,
#        2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4,
#        3, 3, 2, 2, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 3, 3,
#        3, 3, 4, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 4, 2, 3, 2, 3, 3, 4,
#        3, 4, 3, 2, 2, 3, 2, 3, 3, 3, 4, 3, 3, 2, 3, 3, 3, 3, 3, 3, 4, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 4, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3,
#        3, 3, 3, 3, 3, 4, 2, 3, 2, 3, 3, 3, 4, 3, 3, 2, 3, 3, 3, 3, 3, 3,
#        4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 3, 3, 2, 4, 4, 3, 3, 4, 3,
#        2, 3, 3, 3, 3, 3, 2, 2, 4, 2, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3],
#       dtype=int64)

# %%
MYARRAY = y_predict_rf
MYARRAY
# Out:
# array([3, 4, 3, 3, 3, 2, 2, 3, 3, 3, 3, 4, 3, 3, 3, 2, 3, 2, 3, 3, 2, 3,
#        3, 3, 3, 3, 4, 3, 3, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 4,
#        2, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 4, 3, 3,
#        2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4,
#        3, 3, 2, 2, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 3, 3,
#        3, 3, 4, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 4, 2, 3, 2, 3, 3, 4,
#        3, 4, 3, 2, 2, 3, 2, 3, 3, 3, 4, 3, 3, 2, 3, 3, 3, 3, 3, 3, 4, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 4, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3,
#        3, 3, 3, 3, 3, 4, 2, 3, 2, 3, 3, 3, 4, 3, 3, 2, 3, 3, 3, 3, 3, 3,
#        4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 3, 3, 2, 4, 4, 3, 3, 4, 3,
#        2, 3, 3, 3, 3, 3, 2, 2, 4, 2, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3],
#       dtype=int64)

# %%
# Convert the array to a DataFrame
my_dataframe = pd.DataFrame(MYARRAY)
my_dataframe
# Out:
#      0
# 0    3
# 1    4
# 2    3
# 3    3
# 4    3
# ..  ..
# 235  3
# 236  3
# 237  3
# 238  3
# 239  3
#
# [240 rows x 1 columns]

# %%
DF2 = my_dataframe.rename(columns={0:'PerformanceRating'})
DF2
# Out:
#      PerformanceRating
# 0                    3
# 1                    4
# 2                    3
# 3                    3
# 4                    3
# ..                 ...
# 235                  3
# 236                  3
# 237                  3
# 238                  3
# 239                  3
#
# [240 rows x 1 columns]

# %%
ARRAY = X_test
ARRAY
# Out:
# array([[ 0.45234384,  0.20101725,  1.2010435 , ...,  1.02554634,
#          1.47756741,  1.12066982],
#        [ 1.04155698,  0.83720371,  0.28885856, ...,  0.7505395 ,
#         -0.66883402,  1.12066982],
#        [ 1.04155698,  0.83720371,  0.28885856, ..., -0.6244947 ,
#         -0.36220524, -0.58973245],
#        ...,
#        [-0.72608244, -1.07135567,  1.2010435 , ...,  0.7505395 ,
#         -0.66883402,  0.83560277],
#        [ 0.45234384, -0.0110449 , -1.53551131, ..., -0.07448102,
#         -0.66883402, -0.58973245],
#        [ 1.04155698,  0.83720371,  0.28885856, ..., -0.07448102,
#         -0.66883402, -0.3046654 ]])

# %%
my_dataframe2 = pd.DataFrame(ARRAY)
my_dataframe2
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.452344  0.201017  1.201044 -1.167988 -1.057590  1.086876  1.025546
# 1    1.041557  0.837204  0.288859 -0.053130  1.790338  0.457468  0.750540
# 2    1.041557  0.837204  0.288859  0.504299  0.366374 -0.643996 -0.624495
# 3    1.041557  1.049266  0.288859 -0.889273  0.366374 -0.958700 -1.174508
# 4    1.041557  1.049266 -0.623326  1.340442 -1.057590 -0.486644 -0.624495
# ..        ...       ...       ...       ...       ...       ...       ...
# 235  1.041557  1.049266  1.201044 -0.331844  0.366374 -0.643996 -0.624495
# 236 -1.315296  1.261328  1.201044 -0.610559  0.366374 -0.801348 -0.624495
# 237 -0.726082 -1.071356  1.201044 -1.167988  0.366374 -0.014588  0.750540
# 238  0.452344 -0.011045 -1.535511  1.897871  0.366374 -0.329292 -0.074481
# 239  1.041557  0.837204  0.288859 -1.167988  1.790338 -0.329292 -0.074481
#
#             7         8
# 0    1.477567  1.120670
# 1   -0.668834  1.120670
# 2   -0.362205 -0.589732
# 3   -0.668834 -1.159867
# 4   -0.668834 -0.304665
# ..        ...       ...
# 235 -0.362205 -0.589732
# 236 -0.055576 -0.589732
# 237 -0.668834  0.835603
# 238 -0.668834 -0.589732
# 239 -0.668834 -0.304665
#
# [240 rows x 9 columns]

# %%
DF3 = my_dataframe2.rename(columns={0:'EmpDepartment',1:'EmpJobRole', 2:'EmpEnvironmentSatisfaction',3:'EmpLastSalaryHikePercent', 4:'EmpWorkLifeBalance', 5:'ExperienceYearsAtThisCompany',6:'ExperienceYearsInCurrentRole', 7:'YearsSinceLastPromotion', 8:'YearsWithCurrManager'})
DF3
# Out:
#      EmpDepartment  EmpJobRole  EmpEnvironmentSatisfaction  \
# 0         0.452344    0.201017                    1.201044
# 1         1.041557    0.837204                    0.288859
# 2         1.041557    0.837204                    0.288859
# 3         1.041557    1.049266                    0.288859
# 4         1.041557    1.049266                   -0.623326
# ..             ...         ...                         ...
# 235       1.041557    1.049266                    1.201044
# 236      -1.315296    1.261328                    1.201044
# 237      -0.726082   -1.071356                    1.201044
# 238       0.452344   -0.011045                   -1.535511
# 239       1.041557    0.837204                    0.288859
#
#      EmpLastSalaryHikePercent  EmpWorkLifeBalance  \
# 0                   -1.167988           -1.057590
# 1                   -0.053130            1.790338
# 2                    0.504299            0.366374
# 3                   -0.889273            0.366374
# 4                    1.340442           -1.057590
# ..                        ...                 ...
# 235                 -0.331844            0.366374
# 236                 -0.610559            0.366374
# 237                 -1.167988            0.366374
# 238                  1.897871            0.366374
# 239                 -1.167988            1.790338
#
#      ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                        1.086876                      1.025546
# 1                        0.457468                      0.750540
# 2                       -0.643996                     -0.624495
# 3                       -0.958700                     -1.174508
# 4                       -0.486644                     -0.624495
# ..                            ...                           ...
# 235                     -0.643996                     -0.624495
# 236                     -0.801348                     -0.624495
# 237                     -0.014588                      0.750540
# 238                     -0.329292                     -0.074481
# 239                     -0.329292                     -0.074481
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                   1.477567              1.120670
# 1                  -0.668834              1.120670
# 2                  -0.362205             -0.589732
# 3                  -0.668834             -1.159867
# 4                  -0.668834             -0.304665
# ..                       ...                   ...
# 235                -0.362205             -0.589732
# 236                -0.055576             -0.589732
# 237                -0.668834              0.835603
# 238                -0.668834             -0.589732
# 239                -0.668834             -0.304665
#
# [240 rows x 9 columns]

# %%
RFMODELPRED = pd.concat([DF3, DF2], axis=1)
RFMODELPRED
# Out:
#      EmpDepartment  EmpJobRole  EmpEnvironmentSatisfaction  \
# 0         0.452344    0.201017                    1.201044
# 1         1.041557    0.837204                    0.288859
# 2         1.041557    0.837204                    0.288859
# 3         1.041557    1.049266                    0.288859
# 4         1.041557    1.049266                   -0.623326
# ..             ...         ...                         ...
# 235       1.041557    1.049266                    1.201044
# 236      -1.315296    1.261328                    1.201044
# 237      -0.726082   -1.071356                    1.201044
# 238       0.452344   -0.011045                   -1.535511
# 239       1.041557    0.837204                    0.288859
#
#      EmpLastSalaryHikePercent  EmpWorkLifeBalance  \
# 0                   -1.167988           -1.057590
# 1                   -0.053130            1.790338
# 2                    0.504299            0.366374
# 3                   -0.889273            0.366374
# 4                    1.340442           -1.057590
# ..                        ...                 ...
# 235                 -0.331844            0.366374
# 236                 -0.610559            0.366374
# 237                 -1.167988            0.366374
# 238                  1.897871            0.366374
# 239                 -1.167988            1.790338
#
#      ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                        1.086876                      1.025546
# 1                        0.457468                      0.750540
# 2                       -0.643996                     -0.624495
# 3                       -0.958700                     -1.174508
# 4                       -0.486644                     -0.624495
# ..                            ...                           ...
# 235                     -0.643996                     -0.624495
# 236                     -0.801348                     -0.624495
# 237                     -0.014588                      0.750540
# 238                     -0.329292                     -0.074481
# 239                     -0.329292                     -0.074481
#
#      YearsSinceLastPromotion  YearsWithCurrManager  PerformanceRating
# 0                   1.477567              1.120670                  3
# 1                  -0.668834              1.120670                  4
# 2                  -0.362205             -0.589732                  3
# 3                  -0.668834             -1.159867                  3
# 4                  -0.668834             -0.304665                  3
# ..                       ...                   ...                ...
# 235                -0.362205             -0.589732                  3
# 236                -0.055576             -0.589732                  3
# 237                -0.668834              0.835603                  3
# 238                -0.668834             -0.589732                  3
# 239                -0.668834             -0.304665                  3
#
# [240 rows x 10 columns]

# %%
RFMODELPRED.shape
# Out:
# (240, 10)

# %%
RFMODELPRED.size
# Out:
# 2400

# %%
# Save the DataFrame to a CSV file
RFMODELPRED.to_csv('Predectdata.csv', index=False)

# %% [markdown]
# ### Creating the Pickle file for the final model prediction

# %%
import pickle

# %%
# Creating a pickle file for the classifier
filename = 'Emppprediction-rfc-model.pkl'
pickle.dump(modelrf, open(filename, 'wb'))

# %% [markdown]
# ### #                                            E N D Of the Machine Learning Process

# %% [markdown]
# ## NEO4J GRAPH DATABASE CONNECTVITY

# %% [markdown]
# ### Converting the Model Prediction of the Fature values into Neo4j Graph Database to be visulise Graphs

# %%
Neo4jDB = Data
Neo4jDB
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# 2               Sales   Sales Executive       Travel_Frequently
# 3     Human Resources           Manager           Travel_Rarely
# 4               Sales   Sales Executive           Travel_Rarely
# ...               ...               ...                     ...
# 1195            Sales   Sales Executive       Travel_Frequently
# 1196      Development  Senior Developer           Travel_Rarely
# 1197      Development  Senior Developer           Travel_Rarely
# 1198     Data Science    Data Scientist           Travel_Rarely
# 1199            Sales   Sales Executive           Travel_Rarely
#
#       DistanceFromHome  EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                   10                  3  ...                            4
# 1                   14                  4  ...                            4
# 2                    5                  4  ...                            3
# 3                   10                  4  ...                            2
# 4                   16                  4  ...                            4
# ...                ...                ...  ...                          ...
# 1195                 3                  1  ...                            2
# 1196                10                  2  ...                            1
# 1197                28                  1  ...                            3
# 1198                 9                  3  ...                            2
# 1199                 3                  2  ...                            1
#
#       TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                             10                      2                   2
# 1                             20                      2                   3
# 2                             20                      2                   3
# 3                             23                      2                   2
# 4                             10                      1                   3
# ...                          ...                    ...                 ...
# 1195                           6                      3                   3
# 1196                           4                      2                   3
# 1197                          20                      3                   3
# 1198                           9                      3                   4
# 1199                           4                      3                   3
#
#       ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                               10                             7
# 1                                7                             7
# 2                               18                            13
# 3                               21                             6
# 4                                2                             2
# ...                            ...                           ...
# 1195                             6                             5
# 1196                             1                             0
# 1197                            20                             8
# 1198                             8                             7
# 1199                             2                             2
#
#      YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 0                          0                     8         No
# 1                          1                     7         No
# 2                          1                    12         No
# 3                         12                     6         No
# 4                          2                     2         No
# ...                      ...                   ...        ...
# 1195                       0                     4         No
# 1196                       0                     0         No
# 1197                       3                     8         No
# 1198                       7                     7         No
# 1199                       2                     0        Yes
#
#       PerformanceRating
# 0                     3
# 1                     3
# 2                     4
# 3                     3
# 4                     3
# ...                 ...
# 1195                  4
# 1196                  3
# 1197                  3
# 1198                  3
# 1199                  2
#
# [1200 rows x 28 columns]

# %%
Neo4jDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
#  12  EmpJobInvolvement             1200 non-null   int64
#  13  EmpJobLevel                   1200 non-null   int64
#  14  EmpJobSatisfaction            1200 non-null   int64
#  15  NumCompaniesWorked            1200 non-null   int64
#  16  OverTime                      1200 non-null   object
#  17  EmpLastSalaryHikePercent      1200 non-null   int64
#  18  EmpRelationshipSatisfaction   1200 non-null   int64
#  19  TotalWorkExperienceInYears    1200 non-null   int64
#  20  TrainingTimesLastYear         1200 non-null   int64
#  21  EmpWorkLifeBalance            1200 non-null   int64
#  22  ExperienceYearsAtThisCompany  1200 non-null   int64
#  23  ExperienceYearsInCurrentRole  1200 non-null   int64
#  24  YearsSinceLastPromotion       1200 non-null   int64
#  25  YearsWithCurrManager          1200 non-null   int64
#  26  Attrition                     1200 non-null   object
#  27  PerformanceRating             1200 non-null   int64
# dtypes: int64(19), object(9)
# memory usage: 262.6+ KB

# %%
# Seperating Target values to be show graph
GRAPHDB = Neo4jDB.iloc[:,[0,5,6,10,17,21,22,23,24,25,27]]
GRAPHDB
# Out:
#      EmpNumber    EmpDepartment        EmpJobRole  EmpEnvironmentSatisfaction  \
# 0     E1001000            Sales   Sales Executive                           4
# 1     E1001006            Sales   Sales Executive                           4
# 2     E1001007            Sales   Sales Executive                           4
# 3     E1001009  Human Resources           Manager                           2
# 4     E1001010            Sales   Sales Executive                           1
# ...        ...              ...               ...                         ...
# 1195   E100992            Sales   Sales Executive                           4
# 1196   E100993      Development  Senior Developer                           4
# 1197   E100994      Development  Senior Developer                           4
# 1198   E100995     Data Science    Data Scientist                           4
# 1199   E100998            Sales   Sales Executive                           1
#
#       EmpLastSalaryHikePercent  EmpWorkLifeBalance  \
# 0                           12                   2
# 1                           12                   3
# 2                           21                   3
# 3                           15                   2
# 4                           14                   3
# ...                        ...                 ...
# 1195                        20                   3
# 1196                        17                   3
# 1197                        11                   3
# 1198                        14                   4
# 1199                        14                   3
#
#       ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                               10                             7
# 1                                7                             7
# 2                               18                            13
# 3                               21                             6
# 4                                2                             2
# ...                            ...                           ...
# 1195                             6                             5
# 1196                             1                             0
# 1197                            20                             8
# 1198                             8                             7
# 1199                             2                             2
#
#       YearsSinceLastPromotion  YearsWithCurrManager  PerformanceRating
# 0                           0                     8                  3
# 1                           1                     7                  3
# 2                           1                    12                  4
# 3                          12                     6                  3
# 4                           2                     2                  3
# ...                       ...                   ...                ...
# 1195                        0                     4                  4
# 1196                        0                     0                  3
# 1197                        3                     8                  3
# 1198                        7                     7                  3
# 1199                        2                     0                  2
#
# [1200 rows x 11 columns]

# %%
# Save the DataFrame to a CSV file
GRAPHDB.to_csv('GRAPHDB.csv', index=False)

# %% [markdown]
# ### Analysis & Aggeration of the data

# %% [markdown]
# #### 1. Displayig the  Data types

# %%
GRAPHDB.dtypes
# Out:
# EmpNumber                       object
# EmpDepartment                   object
# EmpJobRole                      object
# EmpEnvironmentSatisfaction       int64
# EmpLastSalaryHikePercent         int64
# EmpWorkLifeBalance               int64
# ExperienceYearsAtThisCompany     int64
# ExperienceYearsInCurrentRole     int64
# YearsSinceLastPromotion          int64
# YearsWithCurrManager             int64
# PerformanceRating                int64
# dtype: object

# %%
GRAPHDB.dtypes.value_counts()
# Out:
# int64     8
# object    3
# Name: count, dtype: int64

# %%
GRAPHDB.nunique()
# Out:
# EmpNumber                       1200
# EmpDepartment                      6
# EmpJobRole                        19
# EmpEnvironmentSatisfaction         4
# EmpLastSalaryHikePercent          15
# EmpWorkLifeBalance                 4
# ExperienceYearsAtThisCompany      37
# ExperienceYearsInCurrentRole      19
# YearsSinceLastPromotion           16
# YearsWithCurrManager              18
# PerformanceRating                  3
# dtype: int64

# %% [markdown]
# #### Columun no. 0 : Employee Numbers of Aggrecation

# %%
# identifying the types of Employee Numbers
GRAPHDB["EmpNumber"].unique()#Here displayed the columun'EmpNumber' of number of unique numbers
# Out:
# array(['E1001000', 'E1001006', 'E1001007', ..., 'E100994', 'E100995',
#        'E100998'], dtype=object)

# %%
# Count the Number of uniques of "EmpNumber"
# Get the count of unique employee numbers
#count_unique_emp_numbers = GRAPHDB["EmpNumber"].nunique()
#print(count_unique_emp_numbers)                             # Note : Wc can use this code also

GRAPHDB["EmpNumber"].nunique()
# Out:
# 1200

# %%
EmpNumbers = GRAPHDB["EmpNumber"].unique()  # I have saved it
EmpNumbers
# Out:
# array(['E1001000', 'E1001006', 'E1001007', ..., 'E100994', 'E100995',
#        'E100998'], dtype=object)

# %%
GRAPHDB.loc[:,"EmpNumber"].value_counts()
# Out:
# EmpNumber
# E1001000    1
# E100346     1
# E100342     1
# E100341     1
# E100340     1
#            ..
# E1001718    1
# E1001717    1
# E1001716    1
# E1001713    1
# E100998     1
# Name: count, Length: 1200, dtype: int64

# %%
# 2nd Method to be display it
EmpNumbers_counts = GRAPHDB["EmpNumber"].value_counts().reset_index()
EmpNumbers_counts.columns = ["EmpNumber", "Count"]

print(EmpNumbers_counts)
# Out:
#      EmpNumber  Count
# 0     E1001000      1
# 1      E100346      1
# 2      E100342      1
# 3      E100341      1
# 4      E100340      1
# ...        ...    ...
# 1195  E1001718      1
# 1196  E1001717      1
# 1197  E1001716      1
# 1198  E1001713      1
# 1199   E100998      1
#
# [1200 rows x 2 columns]

# %% [markdown]
# #### Column No.1 :  Employee Departments of Aggrecation

# %%
# identifying the types of Departments
GRAPHDB["EmpDepartment"].unique()      #Here displaying the columun'EmpDepartment' of number of unique numbers
# Out:
# array(['Sales', 'Human Resources', 'Development', 'Data Science',
#        'Research & Development', 'Finance'], dtype=object)

# %%
# Count the Number of uniques of "EmpDepartment"
GRAPHDB["EmpDepartment"].nunique()
# Out:
# 6

# %%
GRAPHDB.loc[:,"EmpDepartment"].value_counts()
# Out:
# EmpDepartment
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: count, dtype: int64

# %%
department_counts = GRAPHDB["EmpDepartment"].value_counts().reset_index()
department_counts.columns = ["EmpDepartment", "Count"]

print(department_counts)
# Out:
#             EmpDepartment  Count
# 0                   Sales    373
# 1             Development    361
# 2  Research & Development    343
# 3         Human Resources     54
# 4                 Finance     49
# 5            Data Science     20

# %%
EmpDepartments = GRAPHDB["EmpDepartment"].unique()
EmpDepartments
# Out:
# array(['Sales', 'Human Resources', 'Development', 'Data Science',
#        'Research & Development', 'Finance'], dtype=object)

# %% [markdown]
# #### Column No.2 :  Employee JobRoles of Aggrecation

# %%
# identifying the types of Employees JobRoles
GRAPHDB["EmpJobRole"].unique()
# Out:
# array(['Sales Executive', 'Manager', 'Developer', 'Sales Representative',
#        'Human Resources', 'Senior Developer', 'Data Scientist',
#        'Senior Manager R&D', 'Laboratory Technician',
#        'Manufacturing Director', 'Research Scientist',
#        'Healthcare Representative', 'Research Director', 'Manager R&D',
#        'Finance Manager', 'Technical Architect', 'Business Analyst',
#        'Technical Lead', 'Delivery Manager'], dtype=object)

# %%
GRAPHDB["EmpJobRole"].nunique()
# Out:
# 19

# %%
GRAPHDB.loc[:,"EmpJobRole"].value_counts()
# Out:
# EmpJobRole
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: count, dtype: int64

# %%
Jobrole_counts = GRAPHDB["EmpJobRole"].value_counts().reset_index()
Jobrole_counts.columns = ["EmpJobRole", "Count"]

print(Jobrole_counts)
# Out:
#                    EmpJobRole  Count
# 0             Sales Executive    270
# 1                   Developer    236
# 2                 Manager R&D     94
# 3          Research Scientist     77
# 4        Sales Representative     69
# 5       Laboratory Technician     64
# 6            Senior Developer     52
# 7                     Manager     51
# 8             Finance Manager     49
# 9             Human Resources     45
# 10             Technical Lead     38
# 11     Manufacturing Director     33
# 12  Healthcare Representative     33
# 13             Data Scientist     20
# 14          Research Director     19
# 15           Business Analyst     16
# 16         Senior Manager R&D     15
# 17           Delivery Manager     12
# 18        Technical Architect      7

# %%
EmpjobRoles = GRAPHDB["EmpJobRole"].unique()
EmpjobRoles
# Out:
# array(['Sales Executive', 'Manager', 'Developer', 'Sales Representative',
#        'Human Resources', 'Senior Developer', 'Data Scientist',
#        'Senior Manager R&D', 'Laboratory Technician',
#        'Manufacturing Director', 'Research Scientist',
#        'Healthcare Representative', 'Research Director', 'Manager R&D',
#        'Finance Manager', 'Technical Architect', 'Business Analyst',
#        'Technical Lead', 'Delivery Manager'], dtype=object)

# %% [markdown]
# #### Column No.3 :  Employee Performance of Aggrecation

# %%
GRAPHDB["PerformanceRating"].unique()
# Out:
# array([3, 4, 2], dtype=int64)

# %%
GRAPHDB["PerformanceRating"].nunique()
# Out:
# 3

# %%
GRAPHDB.loc[:,"PerformanceRating"].value_counts()
# Out:
# PerformanceRating
# 3    874
# 2    194
# 4    132
# Name: count, dtype: int64

# %%
PerformanceRatings = GRAPHDB["PerformanceRating"].unique()
PerformanceRatings
# Out:
# array([3, 4, 2], dtype=int64)

# %% [markdown]
# ### 1.Importing the Neo4j Graph Data base libraries to connection & Visualizing the Neo4j Graphs

# %%
import pandas as pd
import pyodbc
from neo4j import GraphDatabase

# %%
pip install pyodbc neo4j
# Out:
# Collecting pyodbcNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pyodbc-4.0.39-cp311-cp311-win_amd64.whl (69 kB)
#      ---------------------------------------- 0.0/69.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/69.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/69.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/69.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/69.7 kB ? eta -:--:--
#      ---------------- --------------------- 30.7/69.7 kB 100.9 kB/s eta 0:00:01
#      --------------------------------- ---- 61.4/69.7 kB 193.2 kB/s eta 0:00:01
#      --------------------------------- ---- 61.4/69.7 kB 193.2 kB/s eta 0:00:01
#      -------------------------------------- 69.7/69.7 kB 173.2 kB/s eta 0:00:00
# Requirement already satisfied: neo4j in c:\users\hcl\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (5.12.0)
# Requirement already satisfied: pytz in c:\users\hcl\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from neo4j) (2023.3.post1)
# Installing collected packages: pyodbc
# Successfully installed pyodbc-4.0.39

# %%
# Connect to the Neo4j database
neo4j_uri = "bolt://localhost:7687"  # Replace with your Neo4j URI
neo4j_username = "neo4j"  # Replace with your Neo4j username
neo4j_password = "12345678"  # Replace with your Neo4j password

neo4j_driver = GraphDatabase.driver(neo4j_uri, auth=(neo4j_username, neo4j_password))

# %%
session = neo4j_driver.session()
session

# %%
# create node with label, properties

#session = Graphdb.session()

q1= "MERGE (n:EmpNumbers{EmpNumbers: $EmpNumber, name: $EmpNumber})"

for Aname in EmpNumbers:
    x= GRAPHDB.groupby("EmpNumber").get_group(Aname)["EmpNumber"]
    for sname in x:
        p={"EmpNumber":Aname}
        session.run(q1,p)
        
 # search for created node 
q2= "MATCH (n:EmpNumber) RETURN (n)"
nodes=session.run(q2)
for node in nodes:
       print(node)

# %%
#q2= "CREATE (n:EmpDept{name:'EmpDepartment'})"
# create node with label, properties

session = Graphdb.session()

q1= "CREATE (n:EmpDepartments{EmpDepartments: $EmpDepartment, name: $EmpDepartment})"

for Aname in EmpDepartments:
    x= GRAPHDB.groupby("EmpDepartment").get_group(Aname)["EmpDepartment"]
    for sname in x:
        p={"EmpDepartment":Aname}
        session.run(q1,p)
        
 # search for created node 
q2= "MATCH (n:EmpDepartments) RETURN (n)"
nodes=session.run(q2)
for node in nodes:
       print(node)
# Out:
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2400' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2401' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2402' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2403' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2404' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2405' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2406' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2407' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2408' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2409' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2410' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2411' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2412' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2413' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2414' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2415' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2416' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2417' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2418' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2419' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2420' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2421' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2422' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2423' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2424' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2425' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2426' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2427' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2428' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2429' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2430' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2431' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2432' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2433' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2434' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2435' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2436' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2437' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2438' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2439' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2440' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2441' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2442' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2443' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2444' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2445' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2446' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2447' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2448' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2449' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2450' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2451' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2452' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2453' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2454' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2455' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2456' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2457' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2458' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2459' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2460' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2461' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2462' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2463' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2464' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2465' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2466' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2467' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2468' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2469' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2470' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2471' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2472' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2473' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2474' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2475' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2476' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2477' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2478' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2479' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2480' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2481' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2482' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2483' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2484' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2485' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2486' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2487' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2488' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2489' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2490' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2491' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2492' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2493' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2494' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2495' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2496' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2497' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2498' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2499' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2500' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2501' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2502' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2503' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2504' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2505' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2506' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2507' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2508' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2509' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2510' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2511' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2512' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2513' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2514' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2515' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2516' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2517' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2518' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2519' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2520' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2521' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2522' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2523' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2524' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2525' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2526' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2527' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2528' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2529' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2530' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2531' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2532' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2533' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2534' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2535' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2536' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2537' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2538' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2539' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2540' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2541' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2542' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2543' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2544' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2545' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2546' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2547' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2548' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2549' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2550' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2551' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2552' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2553' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2554' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2555' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2556' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2557' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2558' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2559' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2560' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2561' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2562' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2563' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2564' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2565' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2566' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2567' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2568' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2569' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2570' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2571' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2572' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2573' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2574' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2575' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2576' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2577' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2578' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2579' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2580' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2581' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2582' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2583' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2584' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2585' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2586' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2587' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2588' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2589' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2590' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2591' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2592' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2593' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2594' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2595' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2596' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2597' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2598' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2599' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2600' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2601' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2602' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2603' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2604' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2605' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2606' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2607' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2608' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2609' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2610' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2611' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2612' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2613' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2614' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2615' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2616' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2617' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2618' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2619' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2620' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2621' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2622' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2623' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2624' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2625' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2626' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2627' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2628' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2629' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2630' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2631' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2632' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2633' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2634' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2635' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2636' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2637' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2638' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2639' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2640' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2641' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2642' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2643' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2644' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2645' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2646' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2647' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2648' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2649' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2650' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2651' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2652' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2653' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2654' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2655' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2656' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2657' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2658' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2659' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2660' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2661' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2662' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2663' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2664' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2665' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2666' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2667' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2668' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2669' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2670' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2671' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2672' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2673' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2674' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2675' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2676' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2677' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2678' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2679' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2680' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2681' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2682' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2683' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:2684' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Sales', 'name': 'Sales'}>>
# ...
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3514' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3515' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3516' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3517' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3518' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3519' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3520' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3521' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3522' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3523' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3524' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3525' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3526' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3527' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3528' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3529' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3530' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3531' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3532' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3533' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3534' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3535' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3536' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3537' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3538' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3539' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3540' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3541' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3542' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3543' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3544' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3545' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3546' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3547' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3548' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3549' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3550' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Research & Development', 'name': 'Research & Development'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3551' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3552' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3553' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3554' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3555' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3556' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3557' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3558' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3559' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3560' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3561' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3562' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3563' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3564' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3565' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3566' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3567' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3568' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3569' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3570' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3571' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3572' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3573' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3574' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3575' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3576' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3577' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3578' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3579' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3580' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3581' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3582' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3583' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3584' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3585' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3586' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3587' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3588' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3589' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3590' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3591' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3592' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3593' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3594' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3595' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3596' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3597' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3598' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3599' labels=frozenset({'EmpDepartments'}) properties={'EmpDepartments': 'Finance', 'name': 'Finance'}>>

# %%
# create node with label, properties
#q3= "CREATE (n:EmpJob{name:'EmpJobRole'})"

session = Graphdb.session()

q1= "CREATE (n:EmpjobRoles{EmpjobRole: $EmpJobRole, name: $EmpJobRole})"

for Aname in EmpjobRoles:
    x= GRAPHDB.groupby("EmpJobRole").get_group(Aname)["EmpJobRole"]
    for sname in x:
        p={"EmpJobRole":Aname}
        session.run(q1,p)
        
 # search for created node 
q2= "MATCH (n:EmpjobRoles) RETURN (n)"
nodes=session.run(q2)
for node in nodes:
       print(node)

# %%
# create node with label, properties
#q12= "CREATE (n:PERFRATE{name:'PerformanceRating'})"
session = Graphdb.session()

q1= "CREATE (n:PerformanceRatings{PerformanceRatings: $PerformanceRating, name: $PerformanceRating})"

for Aname in PerformanceRatings:
    x= GRAPHDB.groupby("PerformanceRating").get_group(Aname)["PerformanceRating"]
    for sname in x:
        p={"PerformanceRating":Aname}
        session.run(q1,p)
        
 # search for created node 
q2= "MATCH (n:PerformanceRatings) RETURN (n)"
nodes=session.run(q2)
for node in nodes:
       print(node)
# Out:
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3637' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3638' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3639' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3640' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3641' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3642' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3643' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3644' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3645' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3646' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3647' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3648' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3649' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3650' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3651' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3652' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3653' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3654' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3655' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3656' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3657' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3658' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3659' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3660' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3661' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3662' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3663' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3664' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3665' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3666' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3667' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3668' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3669' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3670' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3671' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3672' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3673' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3674' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3675' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3676' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3677' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3678' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3679' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3680' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3681' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3682' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3683' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3684' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3685' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3686' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3687' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3688' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3689' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3690' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3691' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3692' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3693' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3694' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3695' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3696' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3697' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3698' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3699' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3700' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3701' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3702' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3703' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3704' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3705' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3706' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3707' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3708' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3709' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3710' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3711' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3712' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3713' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3714' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3715' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3716' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3717' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3718' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3719' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3720' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3721' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3722' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3723' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3724' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3725' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3726' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3727' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3728' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3729' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3730' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3731' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3732' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3733' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3734' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3735' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3736' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3737' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3738' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3739' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3740' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3741' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3742' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3743' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3744' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3745' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3746' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3747' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3748' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3749' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3750' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3751' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3752' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3753' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3754' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3755' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3756' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3757' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3758' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3759' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3760' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3761' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3762' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3763' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3764' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3765' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3766' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3767' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3768' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3769' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3770' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3771' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3772' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3773' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3774' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3775' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3776' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3777' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3778' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3779' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3780' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3781' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3782' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3783' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3784' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3785' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3786' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3787' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3788' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3789' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3790' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3791' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3792' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3793' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3794' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3795' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3796' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3797' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3798' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3799' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3800' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3801' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3802' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3803' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3804' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3805' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3806' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3807' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3808' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3809' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3810' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3811' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3812' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3813' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3814' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3815' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3816' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3817' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3818' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3819' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3820' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3821' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3822' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3823' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3824' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3825' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3826' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3827' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3828' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3829' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3830' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3831' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3832' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3833' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3834' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3835' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3836' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3837' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3838' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3839' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3840' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3841' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3842' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3843' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3844' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3845' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3846' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3847' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3848' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3849' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3850' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3851' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3852' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3853' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3854' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3855' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3856' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3857' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3858' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3859' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3860' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3861' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3862' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3863' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3864' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3865' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3866' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3867' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3868' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3869' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3870' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3871' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3872' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3873' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3874' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3875' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3876' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3877' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3878' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3879' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3880' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3881' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3882' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3883' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3884' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3885' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3886' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3887' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3888' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3889' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3890' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3891' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3892' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3893' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3894' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3895' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3896' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3897' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3898' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3899' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3900' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3901' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3902' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3903' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3904' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3905' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3906' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3907' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3908' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3909' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3910' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3911' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3912' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3913' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3914' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3915' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3916' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3917' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3918' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3919' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3920' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3921' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3922' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3923' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3924' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3925' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3926' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3927' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:3928' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 3, 'name': 3}>>
# ...
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4740' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4741' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4742' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4743' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4744' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4745' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4746' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4747' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4748' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4749' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4750' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4751' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4752' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4753' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4754' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4755' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4756' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4757' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4758' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4759' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4760' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4761' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4762' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4763' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4764' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4765' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4766' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4767' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4768' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4769' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4770' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4771' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4772' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4773' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4774' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4775' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4776' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4777' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4778' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4779' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4780' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4781' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4782' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4783' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4784' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4785' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4786' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4787' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4788' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4789' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4790' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4791' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4792' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4793' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4794' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4795' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4796' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4797' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4798' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4799' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4800' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4801' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4802' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4803' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4804' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4805' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4806' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4807' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4808' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4809' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4810' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4811' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4812' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4813' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4814' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4815' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4816' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4817' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4818' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4819' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4820' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4821' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4822' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4823' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4824' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4825' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4826' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4827' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4828' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4829' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4830' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4831' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4832' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4833' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4834' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4835' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>
# <Record n=<Node element_id='4:32f825b2-bc46-4f27-861a-ff7299e3923d:4836' labels=frozenset({'PerformanceRatings'}) properties={'PerformanceRatings': 2, 'name': 2}>>

# %% [markdown]
# ### 2. CREATING RELATIONSHIPS

# %%
pip install neo4j
# Out:
# Requirement already satisfied: neo4j in c:\users\hcl\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (5.12.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pytz in c:\users\hcl\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from neo4j) (2023.3.post1)

# %%
##MERGE(A:Empid{name:'EmpNumber'})
q2="""
MATCH(A:EmpNumbers{EmpNumber:$EmpNumber})
MATCH(B:EmpDepartments{EmpDepartment:$EmpDepartment})
WHERE A.EmpDepartments = B.Name
MERGE (A)-[r:WORKS_IN]->(B)
"""
for Aname in EmpjobRoles:
    x= GRAPHDB.groupby("EmpNumbers")[["EmpNumbers","EmpDepartments"]].get_group(Aname)["EmpNumbers"]
    for sname in x:
        p={"EmpNumber":Aname,"EmpDepartment":sname}
        session.run(q2,p)
        
         # search RELATIONSHIP
session= neo4j_driver .session()
session
q3="MATCH (r:WORKS_IN) return (r)"
relationships=session.run(q3)
for relationship in relationships:
    print(relationship)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Hcl\Desktop\NEO4J GRAPH PROJECTS\NODES 2023 FOR EMPLOYEES PERFORMANCE PROJECT\NEW DEMO\NEO4J Source Code.ipynb Cell 192 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=1'>2</a> q2="""
#       <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=2'>3</a> MATCH(A:EmpNumbers{EmpNumber:$EmpNumber})
#       <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=3'>4</a> MATCH(B:EmpDepartments{EmpDepartment:$EmpDepartment})
#       <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=4'>5</a> WHERE A.EmpDepartments = B.Name
#       <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=5'>6</a> MERGE (A)-[r:WORKS_IN]->(B)
#       <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=6'>7</a> """
#       <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=7'>8</a> for Aname in EmpjobRoles:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=8'>9</a>     x= GRAPHDB.groupby("EmpNumbers")[["EmpNumbers","EmpDepartments"]].get_group(Aname)["EmpNumbers"]
#      <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=9'>10</a>     for sname in x:
#      <a href='vscode-notebook-cell:/c%3A/Users/Hcl/Desktop/NEO4J%20GRAPH%20PROJECTS/NODES%202023%20FOR%20EMPLOYEES%20PERFORMANCE%20PROJECT/NEW%20DEMO/NEO4J%20Source%20Code.ipynb#Y435sZmlsZQ%3D%3D?line=10'>11</a>         p={"EmpNumber":Aname,"EmpDepartment":sname}
#
# AttributeError: 'str' object has no attribute 'groupby'
